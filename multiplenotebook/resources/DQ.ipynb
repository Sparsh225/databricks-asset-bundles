# %%
print("start of notebook")

# %%
sampledata =((111,"sparsh",8),(222,"bob",5),(111,"sparsh",8),(222,"bob",12))

columns =["id","name","score"]

df=spark.createDataFrame(sampledata,columns)
df.display()

# %%
df.distinct().display()

# %%
df.select("id","name").distinct().display()

# %%
df.dropDuplicates().display()
